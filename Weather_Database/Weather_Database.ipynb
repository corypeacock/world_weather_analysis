# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# create a set of random lat and long combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the lats and longs to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding cities
cities = []

# id the nearest city for each lat/long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# print city count to confirm sufficient count
len(cities)
# Out:
# 766

# %%
# import the requests library
import requests

# import the API key
from config import weather_api_key

# url for weather map api
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
# import time library and datetime mod
import time
from datetime import datetime

# %%
# create an empty list to hold the weather data
city_data = []

# print the beginning of the logging
print('Beginning Data Retrieval')
print('------------------------')

# create counters
record_count = 1
set_count = 1

# loop through all cities in list
for i, city in enumerate(cities):
    
    # group cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create endpoint url w/ each city
    city_url = url + '&q=' + city.replace(' ','+')
    
    # log the url, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # add 1 to record count
    record_count += 1
    
    # run an api req for each of the cities
    try:
        # parse json and retrieve data
        city_weather = requests.get(city_url).json()
        
        # parse out needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        
        # convert date to ISO
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # append city info to city_data list
        city_data.append({'City': city.title(),
                         'Country': city_country,
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_weather_description,
                         'Date': city_date})
        
    # if error, skip the city
    except:
        print('City not found. Skipping...')
        pass
    
# indicate that data loading is complete
print('------------------------')
print('Data Retrieval Complete.')
print('------------------------')
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | havre-saint-pierre
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | vung tau
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | trairi
# Processing Record 8 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 1 | awbari
# Processing Record 10 of Set 1 | beterou
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | kaeo
# Processing Record 15 of Set 1 | pokhara
# Processing Record 16 of Set 1 | ambilobe
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | viedma
# Processing Record 19 of Set 1 | general pico
# Processing Record 20 of Set 1 | half moon bay
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | praia da vitoria
# Processing Record 23 of Set 1 | vazante
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | rodrigues alves
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | bilma
# Processing Record 29 of Set 1 | deputatskiy
# Processing Record 30 of Set 1 | ayolas
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | fereydun kenar
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | imeni poliny osipenko
# Processing Record 40 of Set 1 | beipiao
# Processing Record 41 of Set 1 | groningen
# Processing Record 42 of Set 1 | naze
# Processing Record 43 of Set 1 | mozaceni
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | batagay
# Processing Record 47 of Set 1 | pevek
# Processing Record 48 of Set 1 | el alto
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | jiuquan
# Processing Record 2 of Set 2 | menongue
# Processing Record 3 of Set 2 | san andres
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | kruisfontein
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | anloga
# Processing Record 8 of Set 2 | opobo
# City not found. Skipping...
# Processing Record 9 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | byron bay
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 2 | aykhal
# Processing Record 15 of Set 2 | haines junction
# Processing Record 16 of Set 2 | longyearbyen
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | amahai
# Processing Record 19 of Set 2 | pocone
# Processing Record 20 of Set 2 | saint-felicien
# Processing Record 21 of Set 2 | kon tum
# Processing Record 22 of Set 2 | airai
# Processing Record 23 of Set 2 | kautokeino
# Processing Record 24 of Set 2 | manono
# Processing Record 25 of Set 2 | oranjemund
# Processing Record 26 of Set 2 | kang
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | linjiang
# Processing Record 29 of Set 2 | conceicao do araguaia
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | kirovskiy
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | tuyen quang
# Processing Record 39 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 2 | porto murtinho
# Processing Record 41 of Set 2 | salalah
# Processing Record 42 of Set 2 | san ramon
# Processing Record 43 of Set 2 | karlskrona
# Processing Record 44 of Set 2 | cayenne
# Processing Record 45 of Set 2 | kankon
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | la reforma
# Processing Record 48 of Set 2 | vostok
# Processing Record 49 of Set 2 | tonantins
# Processing Record 50 of Set 2 | lastoursville
# Processing Record 1 of Set 3 | ulaanbaatar
# Processing Record 2 of Set 3 | erzin
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | manjeshwar
# Processing Record 6 of Set 3 | saint-philippe
# Processing Record 7 of Set 3 | shimoda
# Processing Record 8 of Set 3 | victoria
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | dalianwan
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | umuarama
# Processing Record 14 of Set 3 | punta arenas
# Processing Record 15 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | busselton
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | fuling
# Processing Record 20 of Set 3 | port hardy
# Processing Record 21 of Set 3 | namibe
# Processing Record 22 of Set 3 | margate
# Processing Record 23 of Set 3 | egvekinot
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 27 of Set 3 | boca do acre
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | wattegama
# Processing Record 30 of Set 3 | miles city
# Processing Record 31 of Set 3 | moba
# Processing Record 32 of Set 3 | teguldet
# Processing Record 33 of Set 3 | hay river
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | timra
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | srivardhan
# Processing Record 38 of Set 3 | chokurdakh
# Processing Record 39 of Set 3 | luanda
# Processing Record 40 of Set 3 | poum
# Processing Record 41 of Set 3 | alice springs
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | bilibino
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | kuching
# Processing Record 46 of Set 3 | acapulco
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 3 | mineros
# Processing Record 50 of Set 3 | skjervoy
# Processing Record 1 of Set 4 | aguadilla
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | pisco
# Processing Record 5 of Set 4 | idlib
# Processing Record 6 of Set 4 | bolshiye berezniki
# City not found. Skipping...
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | bambous virieux
# Processing Record 11 of Set 4 | ossora
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | pangnirtung
# Processing Record 14 of Set 4 | vikulovo
# Processing Record 15 of Set 4 | sukhobuzimskoye
# Processing Record 16 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 4 | edd
# Processing Record 18 of Set 4 | fort nelson
# Processing Record 19 of Set 4 | impfondo
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | flower mound
# Processing Record 23 of Set 4 | katsuura
# Processing Record 24 of Set 4 | rocha
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | sao gabriel da cachoeira
# Processing Record 27 of Set 4 | baker city
# Processing Record 28 of Set 4 | qandala
# Processing Record 29 of Set 4 | niquelandia
# Processing Record 30 of Set 4 | diffa
# Processing Record 31 of Set 4 | vilhena
# Processing Record 32 of Set 4 | kodiak
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | marin
# Processing Record 35 of Set 4 | bacolod
# Processing Record 36 of Set 4 | araouane
# Processing Record 37 of Set 4 | apaseo el alto
# Processing Record 38 of Set 4 | vangaindrano
# Processing Record 39 of Set 4 | hualmay
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | nova olimpia
# Processing Record 42 of Set 4 | ostrovnoy
# Processing Record 43 of Set 4 | san vicente
# Processing Record 44 of Set 4 | mayenne
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | sulangan
# Processing Record 49 of Set 4 | katherine
# Processing Record 50 of Set 4 | isangel
# Processing Record 1 of Set 5 | los llanos de aridane
# Processing Record 2 of Set 5 | aklavik
# Processing Record 3 of Set 5 | georgetown
# Processing Record 4 of Set 5 | copiapo
# Processing Record 5 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 5 | nuuk
# Processing Record 7 of Set 5 | rawson
# Processing Record 8 of Set 5 | santa isabel do rio negro
# Processing Record 9 of Set 5 | togul
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | battle creek
# Processing Record 12 of Set 5 | santarem
# Processing Record 13 of Set 5 | chulman
# Processing Record 14 of Set 5 | ponta do sol
# Processing Record 15 of Set 5 | xam nua
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | fairbanks
# Processing Record 18 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | moyale
# Processing Record 21 of Set 5 | san pedro
# Processing Record 22 of Set 5 | olinda
# Processing Record 23 of Set 5 | revin
# Processing Record 24 of Set 5 | bintulu
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | tucurui
# Processing Record 27 of Set 5 | san cristobal
# Processing Record 28 of Set 5 | dudinka
# Processing Record 29 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 5 | prado
# Processing Record 31 of Set 5 | necochea
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | kariba
# Processing Record 34 of Set 5 | port pirie
# Processing Record 35 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 5 | polyarnyy
# Processing Record 37 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | klaksvik
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 5 | nagornskiy
# Processing Record 42 of Set 5 | semey
# Processing Record 43 of Set 5 | presidencia roque saenz pena
# Processing Record 44 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 5 | cap malheureux
# Processing Record 46 of Set 5 | grajau
# Processing Record 47 of Set 5 | liberal
# Processing Record 48 of Set 5 | dikson
# Processing Record 49 of Set 5 | aswan
# Processing Record 50 of Set 5 | takoradi
# Processing Record 1 of Set 6 | nemuro
# Processing Record 2 of Set 6 | tupik
# Processing Record 3 of Set 6 | churapcha
# Processing Record 4 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 6 | east london
# Processing Record 6 of Set 6 | requena
# Processing Record 7 of Set 6 | ituverava
# Processing Record 8 of Set 6 | lang suan
# Processing Record 9 of Set 6 | teguise
# Processing Record 10 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 6 | tivaouane
# Processing Record 12 of Set 6 | thompson
# Processing Record 13 of Set 6 | saint anthony
# Processing Record 14 of Set 6 | muros
# Processing Record 15 of Set 6 | aurich
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | beringovskiy
# Processing Record 18 of Set 6 | kamaishi
# Processing Record 19 of Set 6 | bengkulu
# Processing Record 20 of Set 6 | eyl
# Processing Record 21 of Set 6 | mbandaka
# Processing Record 22 of Set 6 | alyangula
# Processing Record 23 of Set 6 | general roca
# Processing Record 24 of Set 6 | saskylakh
# Processing Record 25 of Set 6 | quatre cocos
# Processing Record 26 of Set 6 | manggar
# Processing Record 27 of Set 6 | tiznit
# Processing Record 28 of Set 6 | hoa binh
# Processing Record 29 of Set 6 | nyrob
# Processing Record 30 of Set 6 | sunyani
# Processing Record 31 of Set 6 | hanstholm
# Processing Record 32 of Set 6 | tuxpan
# Processing Record 33 of Set 6 | siare
# City not found. Skipping...
# Processing Record 34 of Set 6 | nabire
# Processing Record 35 of Set 6 | san luis
# Processing Record 36 of Set 6 | yokadouma
# Processing Record 37 of Set 6 | zakharovo
# Processing Record 38 of Set 6 | altay
# Processing Record 39 of Set 6 | nanortalik
# Processing Record 40 of Set 6 | qui nhon
# Processing Record 41 of Set 6 | nobres
# Processing Record 42 of Set 6 | shizunai
# Processing Record 43 of Set 6 | artesia
# Processing Record 44 of Set 6 | mitsamiouli
# Processing Record 45 of Set 6 | kristianstad
# Processing Record 46 of Set 6 | daru
# Processing Record 47 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | itarema
# Processing Record 50 of Set 6 | elat
# Processing Record 1 of Set 7 | canning
# Processing Record 2 of Set 7 | maniitsoq
# Processing Record 3 of Set 7 | wang saphung
# Processing Record 4 of Set 7 | hofn
# Processing Record 5 of Set 7 | scarborough
# Processing Record 6 of Set 7 | batken
# Processing Record 7 of Set 7 | kargil
# Processing Record 8 of Set 7 | muzhi
# Processing Record 9 of Set 7 | ucluelet
# Processing Record 10 of Set 7 | luena
# Processing Record 11 of Set 7 | kassiopi
# Processing Record 12 of Set 7 | samarai
# Processing Record 13 of Set 7 | taoudenni
# Processing Record 14 of Set 7 | gerash
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | upernavik
# Processing Record 17 of Set 7 | khatanga
# Processing Record 18 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 7 | upington
# Processing Record 20 of Set 7 | martapura
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | belyy yar
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | celestun
# Processing Record 25 of Set 7 | yerbogachen
# Processing Record 26 of Set 7 | townsville
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 7 | debre birhan
# Processing Record 30 of Set 7 | senneterre
# Processing Record 31 of Set 7 | manati
# Processing Record 32 of Set 7 | great yarmouth
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | saint-georges
# Processing Record 35 of Set 7 | alcantarilla
# Processing Record 36 of Set 7 | pescara
# Processing Record 37 of Set 7 | gikongoro
# Processing Record 38 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 7 | richards bay
# Processing Record 40 of Set 7 | woodstock
# Processing Record 41 of Set 7 | vanimo
# Processing Record 42 of Set 7 | kloulklubed
# Processing Record 43 of Set 7 | rio brilhante
# Processing Record 44 of Set 7 | qaqortoq
# Processing Record 45 of Set 7 | poltavka
# Processing Record 46 of Set 7 | srednekolymsk
# Processing Record 47 of Set 7 | codrington
# Processing Record 48 of Set 7 | waipawa
# Processing Record 49 of Set 7 | touros
# Processing Record 50 of Set 7 | brigantine
# Processing Record 1 of Set 8 | takob
# City not found. Skipping...
# Processing Record 2 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 8 | simga
# Processing Record 4 of Set 8 | mangochi
# Processing Record 5 of Set 8 | olafsvik
# Processing Record 6 of Set 8 | kyshtovka
# Processing Record 7 of Set 8 | goundam
# Processing Record 8 of Set 8 | asau
# Processing Record 9 of Set 8 | laguna
# Processing Record 10 of Set 8 | talnakh
# Processing Record 11 of Set 8 | santa cruz
# Processing Record 12 of Set 8 | yakuplu
# Processing Record 13 of Set 8 | contramaestre
# Processing Record 14 of Set 8 | gornopravdinsk
# Processing Record 15 of Set 8 | ulladulla
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | ugoofaaru
# Processing Record 18 of Set 8 | sao joao da barra
# Processing Record 19 of Set 8 | chamba
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | muscat
# Processing Record 22 of Set 8 | xique-xique
# Processing Record 23 of Set 8 | baft
# Processing Record 24 of Set 8 | lexington park
# Processing Record 25 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 8 | dhidhdhoo
# Processing Record 27 of Set 8 | vierzon
# Processing Record 28 of Set 8 | kachkanar
# Processing Record 29 of Set 8 | bambanglipuro
# Processing Record 30 of Set 8 | lazaro cardenas
# Processing Record 31 of Set 8 | dunedin
# Processing Record 32 of Set 8 | bucerias
# Processing Record 33 of Set 8 | kemijarvi
# Processing Record 34 of Set 8 | muttupet
# Processing Record 35 of Set 8 | kelvington
# Processing Record 36 of Set 8 | eureka
# Processing Record 37 of Set 8 | vila praia de ancora
# Processing Record 38 of Set 8 | port blair
# Processing Record 39 of Set 8 | anadyr
# Processing Record 40 of Set 8 | lubao
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | griffith
# Processing Record 43 of Set 8 | cabedelo
# Processing Record 44 of Set 8 | north bend
# Processing Record 45 of Set 8 | boa vista
# Processing Record 46 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 47 of Set 8 | kiunga
# Processing Record 48 of Set 8 | diego de almagro
# Processing Record 49 of Set 8 | grand-santi
# Processing Record 50 of Set 8 | havoysund
# Processing Record 1 of Set 9 | atambua
# Processing Record 2 of Set 9 | tuatapere
# Processing Record 3 of Set 9 | ouadda
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | colchester
# Processing Record 6 of Set 9 | clyde river
# Processing Record 7 of Set 9 | san patricio
# Processing Record 8 of Set 9 | nelson bay
# Processing Record 9 of Set 9 | nisia floresta
# Processing Record 10 of Set 9 | plettenberg bay
# Processing Record 11 of Set 9 | saint-pierre
# Processing Record 12 of Set 9 | marawi
# Processing Record 13 of Set 9 | coquimbo
# Processing Record 14 of Set 9 | jalu
# Processing Record 15 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 16 of Set 9 | hovd
# Processing Record 17 of Set 9 | son la
# Processing Record 18 of Set 9 | camacha
# Processing Record 19 of Set 9 | kyrylivka
# Processing Record 20 of Set 9 | robat karim
# Processing Record 21 of Set 9 | formosa do rio preto
# Processing Record 22 of Set 9 | nhulunbuy
# Processing Record 23 of Set 9 | ahipara
# Processing Record 24 of Set 9 | los palacios
# Processing Record 25 of Set 9 | maldonado
# Processing Record 26 of Set 9 | el faiyum
# City not found. Skipping...
# Processing Record 27 of Set 9 | nishihara
# Processing Record 28 of Set 9 | khandyga
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 32 of Set 9 | ravar
# Processing Record 33 of Set 9 | paita
# Processing Record 34 of Set 9 | puksoozero
# Processing Record 35 of Set 9 | along
# Processing Record 36 of Set 9 | phangnga
# Processing Record 37 of Set 9 | tecoanapa
# Processing Record 38 of Set 9 | quesnel
# Processing Record 39 of Set 9 | vershino-darasunskiy
# Processing Record 40 of Set 9 | portland
# Processing Record 41 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 9 | rochegda
# Processing Record 43 of Set 9 | pyrzyce
# Processing Record 44 of Set 9 | leua
# Processing Record 45 of Set 9 | altamont
# Processing Record 46 of Set 9 | aksarka
# Processing Record 47 of Set 9 | namatanai
# Processing Record 48 of Set 9 | nchelenge
# Processing Record 49 of Set 9 | westport
# Processing Record 50 of Set 9 | dinar
# Processing Record 1 of Set 10 | senanga
# Processing Record 2 of Set 10 | daura
# Processing Record 3 of Set 10 | mabaruma
# Processing Record 4 of Set 10 | george town
# Processing Record 5 of Set 10 | inhambane
# Processing Record 6 of Set 10 | zhigansk
# Processing Record 7 of Set 10 | korla
# Processing Record 8 of Set 10 | makat
# Processing Record 9 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 10 of Set 10 | ler
# Processing Record 11 of Set 10 | winslow
# Processing Record 12 of Set 10 | coacoyul
# Processing Record 13 of Set 10 | gizo
# Processing Record 14 of Set 10 | porto belo
# Processing Record 15 of Set 10 | progreso
# Processing Record 16 of Set 10 | livenka
# Processing Record 17 of Set 10 | miramar
# Processing Record 18 of Set 10 | sioux lookout
# Processing Record 19 of Set 10 | pleasant point
# Processing Record 20 of Set 10 | ust-nera
# Processing Record 21 of Set 10 | ladnun
# Processing Record 22 of Set 10 | najran
# Processing Record 23 of Set 10 | pingdingshan
# Processing Record 24 of Set 10 | inta
# Processing Record 25 of Set 10 | batuan
# Processing Record 26 of Set 10 | zheshart
# Processing Record 27 of Set 10 | samana
# Processing Record 28 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 10 | bar harbor
# Processing Record 30 of Set 10 | khani
# Processing Record 31 of Set 10 | mount isa
# Processing Record 32 of Set 10 | halifax
# Processing Record 33 of Set 10 | wanxian
# Processing Record 34 of Set 10 | marsaxlokk
# Processing Record 35 of Set 10 | varnamo
# Processing Record 36 of Set 10 | khasan
# Processing Record 37 of Set 10 | iracoubo
# Processing Record 38 of Set 10 | sault sainte marie
# Processing Record 39 of Set 10 | carutapera
# Processing Record 40 of Set 10 | manokwari
# Processing Record 41 of Set 10 | lavrentiya
# Processing Record 42 of Set 10 | cockburn town
# Processing Record 43 of Set 10 | mandalgovi
# Processing Record 44 of Set 10 | rocky mountain house
# Processing Record 45 of Set 10 | harnosand
# Processing Record 46 of Set 10 | porto novo
# Processing Record 47 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 10 | huicungo
# Processing Record 49 of Set 10 | salinopolis
# Processing Record 50 of Set 10 | bodaybo
# Processing Record 1 of Set 11 | moose factory
# Processing Record 2 of Set 11 | moron
# Processing Record 3 of Set 11 | praia
# Processing Record 4 of Set 11 | shakawe
# Processing Record 5 of Set 11 | isla mujeres
# Processing Record 6 of Set 11 | hambantota
# Processing Record 7 of Set 11 | batagay-alyta
# Processing Record 8 of Set 11 | kolokani
# Processing Record 9 of Set 11 | pietarsaari
# Processing Record 10 of Set 11 | greenwood
# Processing Record 11 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 11 | fuerte olimpo
# Processing Record 13 of Set 11 | saint-joseph
# Processing Record 14 of Set 11 | avera
# Processing Record 15 of Set 11 | cacu
# Processing Record 16 of Set 11 | hue
# Processing Record 17 of Set 11 | alekseyevsk
# Processing Record 18 of Set 11 | panzhihua
# Processing Record 19 of Set 11 | magadan
# Processing Record 20 of Set 11 | ridgecrest
# Processing Record 21 of Set 11 | ratnagiri
# Processing Record 22 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 11 | karratha
# Processing Record 24 of Set 11 | dingle
# Processing Record 25 of Set 11 | simbahan
# Processing Record 26 of Set 11 | acajutla
# Processing Record 27 of Set 11 | caravelas
# Processing Record 28 of Set 11 | kingman
# Processing Record 29 of Set 11 | morgan city
# Processing Record 30 of Set 11 | nouakchott
# Processing Record 31 of Set 11 | jamame
# Processing Record 32 of Set 11 | dandong
# Processing Record 33 of Set 11 | sitka
# Processing Record 34 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 11 | hueypoxtla
# Processing Record 36 of Set 11 | jijiga
# Processing Record 37 of Set 11 | makakilo city
# Processing Record 38 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 11 | novaya bryan
# Processing Record 40 of Set 11 | kilinochchi
# Processing Record 41 of Set 11 | jumla
# Processing Record 42 of Set 11 | pacasmayo
# Processing Record 43 of Set 11 | la paz
# Processing Record 44 of Set 11 | bikramganj
# Processing Record 45 of Set 11 | puerto colombia
# Processing Record 46 of Set 11 | kasongo
# Processing Record 47 of Set 11 | taua
# Processing Record 48 of Set 11 | conde
# Processing Record 49 of Set 11 | verkhnevilyuysk
# Processing Record 50 of Set 11 | perth
# Processing Record 1 of Set 12 | charlottesville
# Processing Record 2 of Set 12 | abu samrah
# Processing Record 3 of Set 12 | sabang
# Processing Record 4 of Set 12 | naryan-mar
# Processing Record 5 of Set 12 | faya
# Processing Record 6 of Set 12 | agirish
# Processing Record 7 of Set 12 | lujan
# Processing Record 8 of Set 12 | ciudad bolivar
# Processing Record 9 of Set 12 | henties bay
# Processing Record 10 of Set 12 | emerald
# Processing Record 11 of Set 12 | banda aceh
# Processing Record 12 of Set 12 | dongsheng
# Processing Record 13 of Set 12 | tongchuan
# Processing Record 14 of Set 12 | stephenville
# Processing Record 15 of Set 12 | carlsbad
# Processing Record 16 of Set 12 | hengyang
# Processing Record 17 of Set 12 | posse
# Processing Record 18 of Set 12 | rapid valley
# Processing Record 19 of Set 12 | russell
# Processing Record 20 of Set 12 | worland
# Processing Record 21 of Set 12 | troy
# Processing Record 22 of Set 12 | kahului
# Processing Record 23 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 12 | verenchanka
# Processing Record 25 of Set 12 | ribeira brava
# Processing Record 26 of Set 12 | tura
# Processing Record 27 of Set 12 | pouebo
# Processing Record 28 of Set 12 | ayaviri
# Processing Record 29 of Set 12 | barraute
# Processing Record 30 of Set 12 | kaniama
# Processing Record 31 of Set 12 | adre
# Processing Record 32 of Set 12 | maple creek
# Processing Record 33 of Set 12 | wamba
# Processing Record 34 of Set 12 | sinnamary
# Processing Record 35 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 12 | pathein
# Processing Record 37 of Set 12 | labuhan
# Processing Record 38 of Set 12 | sibolga
# Processing Record 39 of Set 12 | beira
# Processing Record 40 of Set 12 | omsukchan
# Processing Record 41 of Set 12 | gallup
# Processing Record 42 of Set 12 | standerton
# Processing Record 43 of Set 12 | vila franca do campo
# Processing Record 44 of Set 12 | kathu
# Processing Record 45 of Set 12 | vardo
# Processing Record 46 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 12 | aasiaat
# Processing Record 48 of Set 12 | kapit
# Processing Record 49 of Set 12 | ojinaga
# Processing Record 50 of Set 12 | dhar
# Processing Record 1 of Set 13 | rioja
# Processing Record 2 of Set 13 | kutum
# Processing Record 3 of Set 13 | palana
# Processing Record 4 of Set 13 | hervey bay
# Processing Record 5 of Set 13 | tilichiki
# Processing Record 6 of Set 13 | omboue
# Processing Record 7 of Set 13 | maxixe
# Processing Record 8 of Set 13 | coari
# Processing Record 9 of Set 13 | sumbe
# Processing Record 10 of Set 13 | coahuayana
# Processing Record 11 of Set 13 | haapu
# City not found. Skipping...
# Processing Record 12 of Set 13 | gezing
# Processing Record 13 of Set 13 | sestri levante
# Processing Record 14 of Set 13 | chapais
# Processing Record 15 of Set 13 | pulawy
# Processing Record 16 of Set 13 | shingu
# Processing Record 17 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 18 of Set 13 | lucapa
# Processing Record 19 of Set 13 | yulara
# Processing Record 20 of Set 13 | pacific grove
# Processing Record 21 of Set 13 | tefe
# Processing Record 22 of Set 13 | el carmen
# Processing Record 23 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 24 of Set 13 | andilamena
# Processing Record 25 of Set 13 | salumbar
# Processing Record 26 of Set 13 | phonhong
# Processing Record 27 of Set 13 | williams lake
# Processing Record 28 of Set 13 | wawa
# Processing Record 29 of Set 13 | dalbandin
# Processing Record 30 of Set 13 | xining
# Processing Record 31 of Set 13 | corn island
# Processing Record 32 of Set 13 | pucallpa
# Processing Record 33 of Set 13 | kununurra
# Processing Record 34 of Set 13 | pangody
# Processing Record 35 of Set 13 | kisangani
# Processing Record 36 of Set 13 | himora
# City not found. Skipping...
# Processing Record 37 of Set 13 | roebourne
# Processing Record 38 of Set 13 | deep river
# Processing Record 39 of Set 13 | motygino
# Processing Record 40 of Set 13 | ola
# Processing Record 41 of Set 13 | morondava
# Processing Record 42 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 13 | angoche
# Processing Record 44 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 45 of Set 13 | havelock
# Processing Record 46 of Set 13 | tyret pervaya
# Processing Record 47 of Set 13 | alofi
# Processing Record 48 of Set 13 | godfrey
# Processing Record 49 of Set 13 | sorong
# Processing Record 50 of Set 13 | port macquarie
# Processing Record 1 of Set 14 | bereda
# Processing Record 2 of Set 14 | parichha
# Processing Record 3 of Set 14 | pereira barreto
# Processing Record 4 of Set 14 | maumere
# Processing Record 5 of Set 14 | launceston
# Processing Record 6 of Set 14 | kudahuvadhoo
# Processing Record 7 of Set 14 | skibbereen
# Processing Record 8 of Set 14 | okhotsk
# Processing Record 9 of Set 14 | sendafa
# Processing Record 10 of Set 14 | macas
# Processing Record 11 of Set 14 | yumen
# Processing Record 12 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 14 | sangin
# Processing Record 14 of Set 14 | vila velha
# Processing Record 15 of Set 14 | yamada
# Processing Record 16 of Set 14 | toungoo
# City not found. Skipping...
# Processing Record 17 of Set 14 | mount gambier
# Processing Record 18 of Set 14 | garowe
# Processing Record 19 of Set 14 | pombia
# Processing Record 20 of Set 14 | krasnoselkup
# Processing Record 21 of Set 14 | yanji
# Processing Record 22 of Set 14 | powassan
# Processing Record 23 of Set 14 | zaozerne
# Processing Record 24 of Set 14 | san roque
# Processing Record 25 of Set 14 | athenry
# Processing Record 26 of Set 14 | vila
# Processing Record 27 of Set 14 | guarda
# Processing Record 28 of Set 14 | iaciara
# Processing Record 29 of Set 14 | digboi
# Processing Record 30 of Set 14 | padang
# Processing Record 31 of Set 14 | faizpur
# Processing Record 32 of Set 14 | oksfjord
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | medea
# Processing Record 35 of Set 14 | umm kaddadah
# Processing Record 36 of Set 14 | san-pedro
# Processing Record 37 of Set 14 | illapel
# Processing Record 38 of Set 14 | bubaque
# Processing Record 39 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 14 | san quintin
# Processing Record 41 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 14 | zambezi
# Processing Record 43 of Set 14 | burns lake
# Processing Record 44 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 14 | kidal
# Processing Record 46 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 14 | sheltozero
# Processing Record 48 of Set 14 | leshukonskoye
# Processing Record 49 of Set 14 | yar-sale
# Processing Record 50 of Set 14 | ubatuba
# Processing Record 1 of Set 15 | broken hill
# Processing Record 2 of Set 15 | victor harbor
# Processing Record 3 of Set 15 | zurrieq
# Processing Record 4 of Set 15 | monywa
# Processing Record 5 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 15 | linchuan
# City not found. Skipping...
# Processing Record 7 of Set 15 | mizdah
# Processing Record 8 of Set 15 | dali
# Processing Record 9 of Set 15 | biloela
# Processing Record 10 of Set 15 | kazminskoye
# City not found. Skipping...
# Processing Record 11 of Set 15 | owando
# Processing Record 12 of Set 15 | yaan
# Processing Record 13 of Set 15 | tazovskiy
# Processing Record 14 of Set 15 | spiridonovka
# Processing Record 15 of Set 15 | takhtamygda
# Processing Record 16 of Set 15 | shangqiu
# Processing Record 17 of Set 15 | sandane
# Processing Record 18 of Set 15 | ekhabi
# Processing Record 19 of Set 15 | namie
# Processing Record 20 of Set 15 | dicabisagan
# Processing Record 21 of Set 15 | taupo
# Processing Record 22 of Set 15 | grand-lahou
# Processing Record 23 of Set 15 | suhbaatar
# Processing Record 24 of Set 15 | north aurora
# Processing Record 25 of Set 15 | yeppoon
# Processing Record 26 of Set 15 | sur
# Processing Record 27 of Set 15 | iranshahr
# Processing Record 28 of Set 15 | kushima
# Processing Record 29 of Set 15 | paamiut
# Processing Record 30 of Set 15 | nurota
# Processing Record 31 of Set 15 | kendari
# Processing Record 32 of Set 15 | high level
# Processing Record 33 of Set 15 | glubczyce
# Processing Record 34 of Set 15 | balsta
# Processing Record 35 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 15 | rio grande
# Processing Record 37 of Set 15 | sayyan
# Processing Record 38 of Set 15 | saquena
# Processing Record 39 of Set 15 | mangrol
# Processing Record 40 of Set 15 | thinadhoo
# Processing Record 41 of Set 15 | brits
# Processing Record 42 of Set 15 | ye
# City not found. Skipping...
# Processing Record 43 of Set 15 | shrigonda
# Processing Record 44 of Set 15 | kushiro
# Processing Record 45 of Set 15 | lalibela
# Processing Record 46 of Set 15 | le port
# Processing Record 47 of Set 15 | kuytun
# Processing Record 48 of Set 15 | luderitz
# Processing Record 49 of Set 15 | ayr
# Processing Record 50 of Set 15 | meadow lake
# Processing Record 1 of Set 16 | bereznik
# Processing Record 2 of Set 16 | porbandar
# Processing Record 3 of Set 16 | lagoa formosa
# Processing Record 4 of Set 16 | mareeba
# Processing Record 5 of Set 16 | holland
# Processing Record 6 of Set 16 | virginia beach
# Processing Record 7 of Set 16 | salinas
# Processing Record 8 of Set 16 | ballina
# Processing Record 9 of Set 16 | vrangel
# Processing Record 10 of Set 16 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 11 of Set 16 | yarada
# Processing Record 12 of Set 16 | northam
# Processing Record 13 of Set 16 | farafangana
# Processing Record 14 of Set 16 | hommelvik
# Processing Record 15 of Set 16 | west wendover
# Processing Record 16 of Set 16 | hirara
# ------------------------
# Data Retrieval Complete.
# ------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# convert array of dictionaries to pandas df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Havre-Saint-Pierre      CA  50.2334  -63.5986      7.16        85
# 1            Souillac      MU -20.5167   57.5167     80.37        85
# 2            Vung Tau      VN  10.3460  107.0843     77.74        81
# 3              Bethel      US  41.3712  -73.4140     25.95        47
# 4      Port Elizabeth      ZA -33.9180   25.5701     75.09        87
# 5              Atuona      PF  -9.8000 -139.0333     77.81        77
# 6              Trairi      BR  -3.2778  -39.2689     77.38        87
# 7              Awbari      LY  26.5921   12.7805     49.44        42
# 8             Beterou      BJ   9.1992    2.2586     81.84        11
# 9       Mar Del Plata      AR -38.0023  -57.5575     84.87        56
#
#    Cloudiness  Wind Speed Current Description                 Date
# 0         100       17.27     overcast clouds  2022-01-30 19:07:06
# 1          84       15.68          light rain  2022-01-30 19:07:07
# 2          52       18.12       broken clouds  2022-01-30 19:07:07
# 3           0        8.05          light snow  2022-01-30 19:07:07
# 4         100       15.57     overcast clouds  2022-01-30 19:07:08
# 5          26       14.65          light rain  2022-01-30 19:07:08
# 6         100        5.77     overcast clouds  2022-01-30 19:07:09
# 7           0        6.51           clear sky  2022-01-30 19:07:09
# 8         100        4.94     overcast clouds  2022-01-30 19:07:10
# 9          75       17.00       broken clouds  2022-01-30 19:07:10

# %%
new_col_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0  Havre-Saint-Pierre      CA  50.2334  -63.5986      7.16        85
# 1            Souillac      MU -20.5167   57.5167     80.37        85
# 2            Vung Tau      VN  10.3460  107.0843     77.74        81
# 3              Bethel      US  41.3712  -73.4140     25.95        47
# 4      Port Elizabeth      ZA -33.9180   25.5701     75.09        87
# 5              Atuona      PF  -9.8000 -139.0333     77.81        77
# 6              Trairi      BR  -3.2778  -39.2689     77.38        87
# 7              Awbari      LY  26.5921   12.7805     49.44        42
# 8             Beterou      BJ   9.1992    2.2586     81.84        11
# 9       Mar Del Plata      AR -38.0023  -57.5575     84.87        56
#
#    Cloudiness  Wind Speed Current Description
# 0         100       17.27     overcast clouds
# 1          84       15.68          light rain
# 2          52       18.12       broken clouds
# 3           0        8.05          light snow
# 4         100       15.57     overcast clouds
# 5          26       14.65          light rain
# 6         100        5.77     overcast clouds
# 7           0        6.51           clear sky
# 8         100        4.94     overcast clouds
# 9          75       17.00       broken clouds

# %%
# create output file, csv
output_data_file = 'WeatherPy_Database.csv'

# export city_data into csv
city_data_df.to_csv(output_data_file, index_label='City_ID')
